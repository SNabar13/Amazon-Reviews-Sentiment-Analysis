# %%
import os
os.chdir("D:")

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
search_query = "nike+shoes+men"

# %%
base_url = "https://www.amazon.com/s?k="

# %%
url=base_url+search_query
url
# Out:
# 'https://www.amazon.com/s?k=nike+shoes+men'

# %%
#header={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36','referer':'https://www.amazon.com/s?k=nike+shoes+men&crid=RTSFGG8DA1DF&sprefix=nike%2Caps%2C332&ref=nb_sb_ss_ts-doa-p_1_4'}

# %%
header = { 
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7", 
    "Accept-Encoding": "gzip, deflate, br", 
    "Accept-Language": "en-US,en;q=0.9", 
    "Upgrade-Insecure-Requests": "1", 
    "Referer": 'https://www.amazon.com/s?k=nike+shoes+men&crid=RTSFGG8DA1DF&sprefix=nike%2Caps%2C332&ref=nb_sb_ss_ts-doa-p_1_4',
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
}

# %%
search_response=requests.get(url,headers=header)

# %%
search_response.status_code
# Out:
# 200

# %%
search_response.text
# Out:
# '<!doctype html><html lang="en-us" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-na.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(
# ...

# %%
search_response.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='i18n-prefs', value='USD', port=None, port_specified=False, domain='.amazon.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1719197893, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='session-id', value='136-6382062-3384441', port=None, port_specified=False, domain='.amazon.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1719197893, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='session-id-time', value='2082787201l', port=None, port_specified=False, domain='.amazon.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1719197893, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='sp-cdn', value='"L5Z9:IN"', port=None, port_specified=Fals
# ...

# %%
cookie={} #insert request cookies within{}
def getAmazonSearch(search_query):
    url="https://www.amazon.com/s?k="+search_query
    print(url)
    page=requests.get(url,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
def Searchasin(asin):
    url="https://www.amazon.com/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
def Searchreviews(review_link):
    url="https://www.amazon.com"+review_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
product_names=[]
response=getAmazonSearch('nike+shoes+men')
soup=BeautifulSoup(response.content)
for a in soup.findAll("span",{'class':"a-size-base-plus a-color-base a-text-normal"}):
    product_names.append(a.text)
# Out:
# https://www.amazon.com/s?k=nike+shoes+men

# %%
product_names
# Out:
# ['Biacolum Mens Running Shoes Non Slip Athletic Walking Fashion Sneakers',
#  "Nike Men's Air Monarch Iv Cross Trainer",
#  "Nike Men's Stroke Running Shoe",
#  "Nike Men's Air Force 1 '07 An20 Basketball Shoe",
#  'Nike Mens Free Rn 2018 Running Shoe',
#  "Nike Men's Sport Trail Running Shoe",
#  "Nike Men's Court Legacy Gymnastics Shoe",
#  "Nike Men's Sneaker",
#  "Nike Men's Flex Control Tr4 Cross Trainer",
#  "Nike Men's Gymnastics Shoes",
#  "PUMA Men's Roma Classic Gum Sneaker",
#  'PUMA Unisex-Adult Smash v2 NBK Sneaker',
#  "Brooks Men's Ghost 15 Neutral Running Shoe",
#  'PUMA Unisex-Adult Smash V2 Sneaker',
#  "Nike Jordan Men's Pro Strong Basketball Shoes",
#  "Nike Men's Air Max 2017 Running Shoe",
#  "Nike Men's Air Max Excee Shoes Anthracite/Black",
#  'Nike React SFB Carbon Men’s Elite Outdoor Shoes',
#  "Nike Men's Running Shoes",
#  "Nike Men's Giannis Immortality White/Metallic Gold-Black (CZ4099 100)",
#  "Nike Men's Basketball Shoe",
# ...

# %%
len(product_names)
# Out:
# 73

# %%
data_asin=[]
response=getAmazonSearch('nike+shoes+men')
soup=BeautifulSoup(response.content)
for a in soup.findAll("div",{'class':"sg-col-4-of-24 sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20"}):
    data_asin.append(a['data-asin'])
# Out:
# https://www.amazon.com/s?k=nike+shoes+men

# %%
search_response.status_code
# Out:
# 200

# %%
data_asin
# Out:
# ['B004IM1GHW',
#  'B000LH8FZE',
#  'B098BJB1V3',
#  'B005AHBJQW',
#  'B08TR7Y16H',
#  'B07QQSXLBK',
#  'B08Q8RH1J4',
#  'B0B6FZK7BF',
#  'B09NSYD4TC',
#  'B07NMY71CQ',
#  'B0B1MBTMHS',
#  'B083FRL7F1',
#  'B09NMK991B',
#  'B0B2PXYHBX',
#  'B004LBMEB2',
#  'B096STZ2DC',
#  'B07YKR15Z8',
#  'B08Q9SCLXM',
#  'B06XSFFX2F',
#  'B07NQMKY3X',
#  'B09NMGKGJN',
#  'B09NMHK4FC',
#  'B0BG8M5R8W',
#  'B0BQX3GZRX',
#  'B078X1CGMZ',
#  'B07RLY3BF8',
#  'B0B6FSQH87',
#  'B07NLYT797',
#  'B07SKKSVQM',
#  'B09F691W8K',
#  'B08JN54TGW',
#  'B07TXRCKRD',
#  'B08XYDPC6K',
#  'B08GJ3D8MC',
#  'B0B6FSNRWF',
#  'B082R5SXB6',
#  'B09M7FCDS3',
#  'B0BR8SM38F',
#  'B095MN75SG',
#  'B0B12Q61FQ',
#  'B00HGVBNQ6',
#  'B07NMZ5XWK',
#  'B08QBCCY89',
#  'B0BRQ7SK82',
#  'B07RFNMWW2',
#  'B005OD857I',
#  'B08XYLLL56',
#  'B09K6QQ8DR']

# %%
len(data_asin)
# Out:
# 48

# %%
link=[]
for i in range(len(data_asin)):
    response=Searchasin(data_asin[i])
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i['href'])
# Out:
# https://www.amazon.com/dp/B004IM1GHW
# https://www.amazon.com/dp/B000LH8FZE
# https://www.amazon.com/dp/B098BJB1V3
# https://www.amazon.com/dp/B005AHBJQW
# https://www.amazon.com/dp/B08TR7Y16H
# https://www.amazon.com/dp/B07QQSXLBK
# https://www.amazon.com/dp/B08Q8RH1J4
# https://www.amazon.com/dp/B0B6FZK7BF
# https://www.amazon.com/dp/B09NSYD4TC
# https://www.amazon.com/dp/B07NMY71CQ
# https://www.amazon.com/dp/B0B1MBTMHS
# https://www.amazon.com/dp/B083FRL7F1
# https://www.amazon.com/dp/B09NMK991B
# https://www.amazon.com/dp/B0B2PXYHBX
# https://www.amazon.com/dp/B004LBMEB2
# https://www.amazon.com/dp/B096STZ2DC
# https://www.amazon.com/dp/B07YKR15Z8
# https://www.amazon.com/dp/B08Q9SCLXM
# https://www.amazon.com/dp/B06XSFFX2F
# https://www.amazon.com/dp/B07NQMKY3X
# https://www.amazon.com/dp/B09NMGKGJN
# https://www.amazon.com/dp/B09NMHK4FC
# https://www.amazon.com/dp/B0BG8M5R8W
# https://www.amazon.com/dp/B0BQX3GZRX
# https://www.amazon.com/dp/B078X1CGMZ
# ...

# %%
len(link)
# Out:
# 93

# %%
link
# Out:
# ['/Nike-Mens-Monarch-Cross-Trainer/product-reviews/B07RJTN4CS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Nike-Mens-Monarch-Cross-Trainer/product-reviews/B07RJTN4CS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/NIKE-Mens-2018-Running-Shoe/product-reviews/B000M5CRC2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/NIKE-Mens-2018-Running-Shoe/product-reviews/B000M5CRC2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Nike-Mens-Running-Shoe/product-reviews/B07ZTTZB9K/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Nike-Mens-Running-Shoe/product-reviews/B07ZTTZB9K/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Nike-Mens-Sneaker-Running-Shoes/product-reviews/B07C5DJ6LC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
#  '/Nike-Mens-Sneaker-Running-Shoes/product-reviews/B07C5DJ6LC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
# ...

# %%
reviews=[]
for j in range(len(link)):
    for k in range(10):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            reviews.append(i.text)
# Out:
# https://www.amazon.com/Nike-Mens-Monarch-Cross-Trainer/product-reviews/B07RJTN4CS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.com/Nike-Mens-Monarch-Cross-Trainer/product-reviews/B07RJTN4CS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.com/Nike-Mens-Monarch-Cross-Trainer/product-reviews/B07RJTN4CS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.com/Nike-Mens-Monarch-Cross-Trainer/product-reviews/B07RJTN4CS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.com/Nike-Mens-Monarch-Cross-Trainer/product-reviews/B07RJTN4CS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.com/Nike-Mens-Monarch-Cross-Trainer/product-reviews/B07RJTN4CS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
len(reviews)
# Out:
# 7971

# %%
reviews
# Out:
# ['\nI got these because when i was going on walks with my dog, my feet would be the ones BARKING. I would wear my Crocs or my Adidas but my feet and knees would be hurtin like crazy. I recently moved into the suburbs so ive been doing alot more walking then i used to, so it made sense. I noticed that whenever I would walk, I would see all the suburban Dads walking  and I would notice how they didnt look pained at all. They looked unbothered, moisturized, happy, in their lanes, focused and flourishing and I couldnt figure out how/why til i noticed something they all had in common...they were rocking NARCHS. I internally debated purchasing these..."But Anon you arent a middle aged surburban Dad, you\'re a 30 something year old latino woman, these arent for you" "But Anon they\'re so ugly though, you would lose ALL street cred". Finally after debating for a few days, I came back from a walk with my dog to my feet throbbing. My crocs rubbed on my feet and created sores on the sides. I ha
# ...

# %%
rev={'reviews':reviews}

# %%
review_data=pd.DataFrame.from_dict(rev)
pd.set_option('max_colwidth',800)

# %%
review_data.tail(20)
# Out:
#                                                                                                                                                                                                                                                                                                                                                     reviews
# 7951                                                                                                                                                                                                             \nOrdered grey and orange but received gray and black. Also the air heel seems cheap and almost fully collapses when weight is put on it\n
# ...

# %%
review_data.to_excel('Amazon3.xlsx',index=False)

# %%
data.tail(30)
# Out:
#                                                 reviews  sentiment
# 7843  nach einem monat tragen  fing der rechte schuh...          1
# 7844  die schuhe fingen nach rund 4 wochen an knacke...          1
# 7845  schuhsohle war das allerletzte produkt sie hat...          1
# 7846  haben ihn meinem sohn zum geburtstag geschenkt...          1
# 7847                                        wider gerne          1
# 7848                                              danke          1
# 7849  bought them for my boyfriend  he said they fit...          1
# 7850                             great shoes look great          1
# 7851  the shoes i received have a black swoosh and b...          0
# 7852  i like the shoes because of the yellow in them...          0
# 7853  ordered grey and orange but received gray and ...          1
# 7854  the shoes feel great  they look good and they ...          1
# 7855             muy bonitos  cómodos  ajuste perfecto           1
# ...

# %%
data.to_excel("Final2.xlsx")

# %%
data.duplicated().sum()
# Out:
# 4485

# %%
data1 = data.drop_duplicates()

# %%
data1.shape
# Out:
# (3388, 2)

# %%
data1.to_excel("Final1.xlsx")

# %%
data2 = pd.read_excel("Final1.xlsx")

# %%
data2.head()
# Out:
#                                              reviews  sentiment
# 0  i got these because when i was going on walks ...          1
# 1  the air monarch has been a good shoe for me fo...          1
# 2  i tried the baby powder trick which works for ...          1
# 3  ordered size 15 i wear a 14 still to small but...          0
# 4  you know the saying don t change what works   ...          1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='sentiment',data=data2)
# Out:
# <AxesSubplot:xlabel='sentiment', ylabel='count'>

# %%
import nltk

import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
def remove_stopwords(text):
    x = []
    for i in text.split():
        if i not in stopwords.words('english'):
            x.append(i)
    y = x[:]
    x.clear()
    return y

# %%
data2['reviews'] = data2['reviews'].apply(remove_stopwords)

# %%
import string
def text_process(mess):
    nopunc = [char for char in mess if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
data2['reviews'] = data2['reviews'].apply(text_process)

# %%
data2.head()
# Out:
#                                              reviews  sentiment
# 0  [gotgoingwalksdogfeetwouldonesbarkingwouldwear...          1
# 1  [airmonarchgoodshoelongtimeperfectbetterwearav...          1
# 2  [triedbabypowdertrickworksaddedinsoleslocalrun...          1
# 3          [orderedsize15wear14stillsmallmanageable]          0
# 4    [knowsayingchangeworksworkalwaysbestpricefound]          1

# %%
#Stemming

from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
y = []
def stem_words(text):
    for i in text:
        y.append(ps.stem(i))
    z = y[:]
    y.clear()
    return z

# %%
data2['reviews'] = data2['reviews'].apply(stem_words)

# %%
data2.head()
# Out:
#                                              reviews  sentiment
# 0  [gotgoingwalksdogfeetwouldonesbarkingwouldwear...          1
# 1  [airmonarchgoodshoelongtimeperfectbetterwearav...          1
# 2  [triedbabypowdertrickworksaddedinsoleslocalrun...          1
# 3               [orderedsize15wear14stillsmallmanag]          0
# 4    [knowsayingchangeworksworkalwaysbestpricefound]          1

# %%
def join_back(list_input):
    return " ".join(list_input)

# %%
data2['reviews'] = data2['reviews'].apply(join_back)

# %%
data2.head()
# Out:
#                                              reviews  sentiment
# 0  g o t g o i n g w a l k s d o g f e e t w o u ...          1
# 1  a i r m o n a r c h g o o d s h o e l o n g t ...          1
# 2  t r i e d b a b y p o w d e r t r i c k w o r ...          1
# 3  o r d e r e d s i z e 1 5 w e a r 1 4 s t i l ...          0
# 4  k n o w s a y i n g c h a n g e w o r k s w o ...          1

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer = CountVectorizer(analyzer=text_process).fit(data2['reviews'])

# %%
print(len(bow_transformer.vocabulary_))
# Out:
# 3276

# %%
mess4 = data2['reviews'][3]

# %%
print(mess4)
# Out:
# orderedsize15wear14stillsmallmanag

# %%
bow4 = bow_transformer.transform([mess4])

# %%
print(bow4)
# Out:
#   (0, 2116)	1

# %%
print(bow4.shape)
# Out:
# (1, 3276)

# %%
bow_transformer.get_feature_names()[4068]
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 bow_transformer.get_feature_names()[4068]
#
# IndexError: list index out of range

# %%
reviews_bow =bow_transformer.transform(data2['reviews'])
print('Shape of sparse matrix: ',reviews_bow.shape)
# Out:
# Shape of sparse matrix:  (3388, 3276)

# %%
reviews_bow.nnz
# Out:
# 3378

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_transformer = TfidfTransformer().fit(reviews_bow)

# %%
tfidf4 = tfidf_transformer.transform(bow4)
print(tfidf4)
# Out:
#   (0, 2116)	1.0

# %%
reviews_tfidf = tfidf_transformer.transform(reviews_bow)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
reveiws_senti_model = MultinomialNB().fit(reviews_tfidf,data2['reviews'])

# %%
reveiws_senti_model.predict(tfidf4)[0]
# Out:
# 'love'

# %%
data2.head(1)
# Out:
#                                              reviews  sentiment
# 0  got go walk dog feet would one bark would wear...          1

# %%
all_pred = reveiws_senti_model.predict(reviews_tfidf)

# %%
all_pred
# Out:
# array(['love', 'love', 'love', ..., 'love', 'love', 'love'],
#       dtype='<U1281')
